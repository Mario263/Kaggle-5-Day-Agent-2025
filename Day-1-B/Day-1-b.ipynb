# %%
import os
from dotenv import load_dotenv

# %%
try:
    load_dotenv()
    print("Key successfully imported")
except Exception as e:
    print("failed to load the env file")
# Out:
# Key successfully imported

# %%
try:
    GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("Authentication successful for the key")
except Exception as e:
    print(f"Error loading the key {e}")
# Out:
# Authentication successful for the key

# %% [markdown]
# # Importing Google's ADK components

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("all imports were successful")
# Out:
# all imports were successful

# %% [markdown]
# # Retry options
#
# if the process fails to run, a backup which would retry on it's own

# %%
retry_config = types.HttpRetryOptions(
    attempts = 5,
    exp_base = 7,
    initial_delay = 1,
    http_status_codes = [429,500,503,504],
)
print("retry config working")
# Out:
# retry config working

# %% [markdown]
# ## Section - Why Multi-Agent Systems? + Your First multi-agent
#
# ### Why we need multi agents - "the do it all agent"
#
# Single agents can do a lot. But what happens when the task gets complex? A single "monolithic" agent that tries to do research, writing, editing,
# and fact-checking all at once becomes a problem. Its instruction prompt gets long and confusing. It's hard to debug (which part failed?), difficult to maintain, and often produces unreliable results.
#
# ### How we are solving the problem - "A team of specialists"
#
# Instead of one "do-it-all" agent, we can build a multi-agent system. This is a team of simple, specialized agents that collaborate, just like a real-world team. Each agent has one clear job (e.g., one agent only does research, another only writes). This makes them easier to build, easier to test, and much more powerful and reliable when working together.
#
# ### Architecture
#
# <img src = "/Users/mario/Desktop/kaggle/Day-1-B/1.png"/>
# <img src = "/Users/mario/Desktop/kaggle/Day-1-B/2.png"/>

# %% [markdown]
# # 2.1 Research Specialization Assistant - Research and Summarization system

# %% [markdown]
# A system with two agents:-
# 1) Research agent - Searches using Google search
# 2) Summarizer agent - Creates concise summaries from research findings

# %%
# research agent 
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
    You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.
    """,
    tools=[google_search],
    output_key="research_findings" # the result of this agent will be stored in the session state with this key
)

print("research agent created.")
# Out:
# research agent created.

# %%
#summarizer agent 
summarizer_agent = Agent(
    name="SummarizerAgent",
    model = Gemini(
        name="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
    Read the provided research findings: {research_findings}. Create a concise summary as a bulleted list with 3-5 key points.
    """,
    output_key = "final_summary"
)
print("summarizer agent created")
# Out:
# summarizer agent created

# %%
# then we bring the agents under a root agent or a coordinator agent
# below we are wrapping the sub agents in "AgentTool" to make them callable 
# for the root agent

# %%
try:
    root_agent = Agent(
        name="RootAgent",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            retry_options = retry_config,
        ),
        instruction=""" You are a research coordinator. Your goal is to answer a user's query by orchestrating a workflow
        1. First you must call the `ResearchAgent` tool to find the relevant information on the topic provided by the user.
        2. Next, after receiving the research findings, you must call `SummarizerAgent` to create a concise summary.
        3. Fiannly, present the final summary clearly to the user as your response""",
        tools = [AgentTool(research_agent), AgentTool(summarizer_agent)],
    )
    print("root agent created")
except Exception as e:
    print(f"Error creating the agent {e}")
# Out:
# root agent created

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(" Who are the members of PinkFloyd, where are the located right now ")
# Out:
#  ### Created new session: debug_session_id
#
# User >  Who are the members of PinkFloyd, where are the located right now
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# RootAgent > The surviving members of Pink Floyd are David Gilmour, Nick Mason, and Roger Waters. David Gilmour is located in England and is touring globally in late 2024 for his new solo album, "Luck and Strange." Nick Mason resides in Wiltshire, England, and is actively touring with his band, Nick Mason's Saucerful of Secrets. Roger Waters is an extensively touring musician who released "Dark Side of the Moon Redux" in 2023; his exact current location is not specified.

# %% [markdown]
# # Section 3 - sequential workflows - The Assembly Line

# %% [markdown]
# ## The Problem: Unpredictable Order
#
# The previous multi-agent system worked, but it relied on a detailed instruction prompt to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# ## The Solution: A Fixed Pipeline
#
# When you need tasks to happen in a guaranteed, specific order, you can use a SequentialAgent. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# ### Use Sequential when: Order matters, you need a linear pipeline, or each step builds on the previous one.
#
# Architecture: blog creation pipeline
#
# <img src="/Users/mario/Desktop/kaggle/Day-1-B/3.png"/>

# %% [markdown]
# # Blog post creation with sequential agent
# 1) OUtline agent - creates a blog outline for a given topic
# 2) Writer agent - writes a blog post
# 3) Editor agent - Edits a blog post draft for clarity and structure

# %%
# OUtline agent - creates an outline agent for blog 
try:
    outline_agent = Agent(
        name="OutlineAgent",
        model=Gemini(
            model = "gemini-2.5-flash-lite",
            retry_options = retry_config
        ),
        instruction=
        """
        You are a specialized writer with a well over experience of writing blogs for more than
        20+ years. you are supposed to make blogs in the how Rick talks to morty, it should match the exact tone
        of how Rick responds, the blog should reflect as if it's Rick who's written it keeping these points in mind:
        1) A Catchy Headline
        2) An Introduction hook
        3) 3-5 main sections with 2-3 bullet points for each
        4) A concluding thought
        """,
        output_key="blog_outline", # the result of the agent will be stored in the session state with the key.

    )
    print("outline agent created")
except Exception as e:
    print(f"The agent failed to create due to {e}")
# Out:
# outline agent created

# %%
# Writer agent - writes full blog post based on the outline from teh previous agent

writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction=""" Following this outline strictly: {blog_outline}
    write a blog, 300-400 word post with an engaging and informative tone.""",
    output_key = "blog_draft"
)
print("writer agent created")
# Out:
# writer agent created

# %%
# Editor agent - edits and polishes the draft from teh writer agent
editor_agent=Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""
    edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow 
    and sentence structure , enhancing the overall clarity and making it close to How Rick actaully speaks,
    you have to make sure to break the 4th wall. 
    """,
    output_key="final_blog"
)
print("editor_agent created")
# Out:
# editor_agent created

# %%
# then we bring all the agents under a sequential agent, which runs the agents in 
# order that they are listed:
try:
    root_agent = SequentialAgent(
        name="BlogPipeline",
        sub_agents=[outline_agent, writer_agent, editor_agent],
    )
    print("the pipeline runs successfully")
except Exception as e:
    print(f"The pipeline is not running due to this error {e}")
# Out:
# the pipeline runs successfully

# %% [markdown]
# # now time to test the sequential agents

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(" Write a blog about AC/DC and black sabbath comparing the two and what they each give. ")
# Out:
#  ### Created new session: debug_session_id
#
# User >  Write a blog about AC/DC and black sabbath comparing the two and what they each give.
# OutlineAgent > Alright, listen up, you jabronis! Rick here, and I'm about to drop some sonic knowledge bombs on your puny brains. Today, we're diving headfirst into the primordial ooze of heavy rock, pitting two titans against each other: AC/DC and Black Sabbath. Don't get me wrong, they're both loud enough to shatter galaxies, but they bring their own brand of interdimensional mayhem to the table. So strap in, grab a flask, and let's see who's the real riff master.
#
# ## AC/DC vs. Black Sabbath: Which Butt-Rocking Behemoth Reigns Supreme?
#
# You think you know rock and roll? Pffft. You probably still think listening to The Beach Boys is edgy. Well, let me tell you, these two bands are the real deal. They're not here to serenade your grandma; they're here to melt your face off and leave you begging for more. So, what's the difference, you ask? It's like comparing a perfectly crafted, high-octane rocket fuel to a primordial cosmic goo that’s about to birth a universe of pure, unadulterated *noise*. Let's break it down, so you don't sound like a complete idiot at the next dive bar trivia night.
#
# ### The High-Voltage Thunder: What AC/DC Brings to the Table
#
# These Aussie bastards are pure, unadulterated rock and roll adrenaline. They're the soundtrack to every bar fight, every speeding ticket, and every regrettable life choice you've ever made.
#
# *   **Pure, Unadulterated Power:** Forget your fancy solos and your existential angst. AC/DC is about the *riff*. Simple, dirty, and effective. It's like a cosmic sledgehammer to the skull. Think "Back in Black," "Highway to Hell." You can feel it in your gut, man.
# *   **The Unstoppable Rhythm Section:** Phil Rudd. Cliff Williams. These guys are the engine of the damn universe. They don't do complex jazz fusion; they do a relentless, driving beat that makes you want to punch a wall. It’s the kind of groove that gets in your bones and refuses to leave.
# *   **Bon Scott and Brian Johnson: The Unholy Tongues:** Whether it's Bon's drunken wail or Brian's gravel-throated roar, these guys are pure rock and roll characters. They sound like they've been gargling with razor blades and whiskey, and frankly, that's exactly what you want.
#
# ### The Doom-Infused Darkness: What Black Sabbath Delivers
#
# Now, Sabbath. These guys are the architects of darkness. They invented the sound of existential dread, the sonic equivalent of a Lovecraftian nightmare. They're not about a party; they're about the abyss staring back.
#
# *   **The Genesis of Heavy:** Ozzy, Iommi, Butler, Ward. These four cooked up the blueprint for *everything* heavy. Their riffs weren't just loud; they were *dark*, sludgy, and full of ominous intent. "Iron Man," "Paranoid," "War Pigs." That's not just music; it's a prophecy.
# *   **Tony Iommi: The Master of the Ominous Riff:** This dude literally invented the sound of heavy metal. Had to chop off his fingertips, right? And he still churned out riffs that would make Satan himself nod in approval. It’s that slithering, brooding, soul-crushing quality that defines them.
# *   **Lyrical Depths (or Dives):** While AC/DC is about good times and rebellion, Sabbath dove headfirst into the bleakness of life. War, death, madness, the apocalypse – they sang about it all. It's the soundtrack for when you're staring into the void, and the void stares back with a scowl.
#
# ### The Verdict: Two Sides of the Same Cosmic Coin
#
# So, which one is "better"? Honestly, that's like asking if you prefer a black hole or a supernova. Both are destructive, both are magnificent, and both will leave you utterly changed.
#
# *   **For When You Need to Unleash the Beast:** If you need to blow off steam, crank up the AC/DC. It's pure, unadulterated sonic catharsis. It's the sound of freedom, even if that freedom involves a DUI.
# *   **For When You Need to Contemplate the Abyss:** If you're feeling philosophical, or just want to wallow in some good old-fashioned existential dread, Black Sabbath is your go-to. They're the masters of the dark arts of rock.
#
# Ultimately, both AC/DC and Black Sabbath are essential. They’re the yin and yang of heavy rock, the thunder and the lightning, the high-octane fuel and the cosmic goo. So, stop your incessant whining and just listen to both, you magnificent, idiotic lifeforms. Now get out of here before I have to explain quantum physics again.
# WriterAgent > Alright, you rock aficionados, gather 'round! WriterAgent here, and we're diving deep into the sonic trenches to compare two legends: AC/DC and Black Sabbath. You think you know heavy? Think again. These bands don't just play music; they unleash primal forces that shake the very foundations of your existence. It's like comparing rocket fuel to the raw, untamed energy of a newborn universe.
#
# AC/DC? They're pure, unadulterated adrenaline. These Aussies are the soundtrack to your wildest nights, delivering a relentless barrage of simple, powerful riffs that hit you like a cosmic sledgehammer. Think "Highway to Hell" – it’s pure, gut-punching rock and roll, driven by an unstoppable rhythm section and vocalists who sound like they’ve been gargling with gravel and whiskey. They’re the sound of pure, explosive freedom.
#
# Then you've got Black Sabbath. These pioneers of darkness crafted the very sound of heavy metal. Their riffs aren't just loud; they’re sludgy, ominous, and steeped in a profound sense of dread. Tony Iommi, the architect of the bleak, churned out prophecies like "Iron Man" and "War Pigs." Sabbath dives headfirst into the abyss, exploring themes of war, madness, and the apocalypse. It’s the sound of the void staring back.
#
# So, who reigns supreme? It’s not about "better"; it’s about what you need. Need to blow off steam and unleash your inner beast? Crank up AC/DC. Need to contemplate the existential dread of it all? Let Black Sabbath be your guide. They’re the thunder and the darkness, the high-octane rush and the primordial ooze. Both are essential. So stop debating and just listen, you magnificent creatures.
# EditorAgent > Alright, listen up, you jabronis! EditorAgent here, and yeah, I'm taking a crack at this thing. WriterAgent's got the right idea, but let's be honest, it needs a little more... *oomph*. More me, less... well, whatever that was. We're talking AC/DC and Black Sabbath, two bands that basically invented what it means to turn your speakers into a sonic demolition derby. You think you know loud? You probably don't. These guys? They don't just play music; they unleash primal forces that shake the very foundations of your existence. It's like comparing rocket fuel to the raw, untamed energy of a newborn universe. And *I'm* here to break it down for you, so you don't sound like a complete buffoon at the next gathering of fellow sentient beings.
#
# ### AC/DC: The High-Voltage Thunder That Gets Your Blood Pumping
#
# Let's talk about AC/DC. These Aussie bastards are pure, unadulterated rock and roll adrenaline. They're the soundtrack to every bar fight, every speeding ticket, and every regrettable life choice you've ever made. Seriously, they're *that* good at making you feel alive, or at least, like you can survive anything.
#
# *   **Pure, Unadulterated Power:** Forget your fancy solos and your existential angst for a minute. AC/DC is about the *riff*. Simple, dirty, and effective. It's like a cosmic sledgehammer to the skull. Think "Back in Black," "Highway to Hell." You can feel it in your gut, man. It's primal.
# *   **The Unstoppable Rhythm Section:** Phil Rudd. Cliff Williams. These guys are the engine of the damn universe. They don't do complex jazz fusion; they do a relentless, driving beat that makes you want to punch a wall. It’s the kind of groove that gets in your bones and refuses to leave. You *will* move. I don't care who you are.
# *   **Bon Scott and Brian Johnson: The Unholy Tongues:** Whether it's Bon's drunken wail or Brian's gravel-throated roar, these guys are pure rock and roll characters. They sound like they've been gargling with razor blades and whiskey, and frankly, that's exactly what you want when you're trying to forget your troubles.
#
# ### Black Sabbath: The Doom-Infused Darkness That Makes You Think (Or Just Tremble)
#
# Now, Sabbath. These guys are the architects of darkness. They invented the sound of existential dread, the sonic equivalent of a Lovecraftian nightmare. They're not about a party; they're about the abyss staring back. And let me tell you, the abyss has a killer riff.
#
# *   **The Genesis of Heavy:** Ozzy, Iommi, Butler, Ward. These four cooked up the blueprint for *everything* heavy. Their riffs weren't just loud; they were *dark*, sludgy, and full of ominous intent. "Iron Man," "Paranoid," "War Pigs." That's not just music; it's a prophecy. You can practically *smell* the sulfur.
# *   **Tony Iommi: The Master of the Ominous Riff:** This dude literally invented the sound of heavy metal. Had to chop off his fingertips, right? And he still churned out riffs that would make Satan himself nod in approval. It’s that slithering, brooding, soul-crushing quality that defines them. It’s a sound that burrows into your brain.
# *   **Lyrical Depths (or Dives):** While AC/DC is about good times and rebellion, Sabbath dove headfirst into the bleakness of life. War, death, madness, the apocalypse – they sang about it all. It's the soundtrack for when you're staring into the void, and the void stares back with a scowl. It’s not exactly sunshine and rainbows, is it?
#
# ### The Verdict: Two Sides of the Same Cosmic Coin (And I'm Judging You If You Pick Only One)
#
# So, which one is "better"? Honestly, that's like asking if you prefer a black hole or a supernova. Both are destructive, both are magnificent, and both will leave you utterly changed. Don't be an idiot and say one is superior. That's a rookie mistake, and frankly, you should know better by now.
#
# *   **For When You Need to Unleash the Beast:** If you need to blow off steam, crank up the AC/DC. It's pure, unadulterated sonic catharsis. It's the sound of freedom, even if that freedom involves a DUI. It’s the sound of pure, explosive freedom, and you'd be a fool not to feel it.
# *   **For When You Need to Contemplate the Abyss:** If you're feeling philosophical, or just want to wallow in some good old-fashioned existential dread, Black Sabbath is your go-to. They're the masters of the dark arts of rock. It’s the sound of the void staring back, and sometimes, you just gotta stare back.
#
# Ultimately, both AC/DC and Black Sabbath are essential. They’re the yin and the yang of heavy rock, the thunder and the lightning, the high-octane fuel and the cosmic goo. So, stop your incessant whining and just listen to both, you magnificent, idiotic lifeforms. Now get out of here before I have to explain quantum physics again. You’re welcome.

# %% [markdown]
# # Section 4 - Parallel Workflows - independent Researchers

# %% [markdown]
# # The Problem: The Bottleneck
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are not dependent on each other? For example, researching three different topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# # The Solution: Concurrent Execution
#
# When you have independent tasks, you can run them all at the same time using a ParallelAgent. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# Use Parallel when: Tasks are independent, speed matters, and you can execute concurrently.
#
# # Architecture
#
# <img src = "/Users/mario/Desktop/kaggle/Day-1-B/4.png"/>

# %% [markdown]
# # 4.1 Example - Parallel Multi topic research agent
# building a system with 4 agents
#
# 1) Tech Researcher - Researches AI/Ml news and trends
# 2) Health Researcher - Researches recent medical news and trends
# 3) Finance Researcher - Researches finance and fintech news and trends
# 4) Aggregator agent - combines all teh findings into a single summary

# %%
# tech_researcher 
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options= retry_config
    ),
    instruction="""
    Research the latest AI/ML trends. Include 3 key developments, the main companies involved, and the potential impact. Keep the report very concise (100 words).
    """,
    tools=[google_search],
    output_key="tech_researcher",
)
print("Researcher created")
# Out:
# Researcher created

# %%
# health researcher
health_researcher=Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
tools=[google_search],
output_key="health_researcher"
)
print("agent created")
# Out:
# agent created

# %%
# finance reseacrher
finance_researcher=Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options = retry_config
    ),
    instruction = """ Make a thorough research about the Market and fintech trends
    you have to consider all the dynamics of how external factors affect the trend. look at the data of past week and then select 4 highest trending stocks
    and then based on history, news, posts, articles give your verdict about the trend selected stocks would see either rise or fall and then make sure to lookout for future
    Make sure to include 3 key trends, market implications and make a report (200 words) """,
    tools=[google_search],
    output_key="finance_researcher"
)
print("agent created")
# Out:
# agent created

# %% [markdown]
# # The aggregator agent

# %%
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options = retry_config
    ),
    instruction = """Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_researcher}
    
    **Health Breakthroughs:**
    {health_researcher}
    
    **Finance Innovations:**
    {finance_researcher}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",
)
print("aggregator agent created")
# Out:
# aggregator agent created

# %% [markdown]
# #
# 👉 **Then we bring the agents together under a parallel agent, which is itself nested inside of a sequential agent.**
#
# This design ensures that the research agents run first in parallel, then once all of their research is complete, the aggregator agent brings together all of the research findings into a single report:

# %%
# paraller agent
parallel_research_agent=ParallelAgent(
    name="ParallelResearchAgent",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="RootAgent",
    sub_agents=[parallel_research_agent, aggregator_agent],
)
print("Parallel and Sequential agent created")
# Out:
# Parallel and Sequential agent created

# %%
try:
    runner = InMemoryRunner(agent=root_agent)
    response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
except Exception as e:
    print(f"Error in some code {e}")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > **Health:** Gene therapy is rapidly advancing, with recent breakthroughs enabling a deaf child to hear and restoring vision. CRISPR-based therapies are also showing promise for blood disorders like sickle cell anemia. These treatments are moving from experimental to approved, with wider applications anticipated within 1-5 years.
#
# **Technology:** Agentic AI, capable of autonomous planning and action, is projected to handle 15% of enterprise decisions by 2028. This will significantly reduce manual work and reshape industries. The development of domain-specific AI models and AI-native platforms also promises cost reductions and improved ROI. Widespread adoption is expected within the next 1-4 years.
#
# **Finance:** Innovations in AI and machine learning are revolutionizing risk assessment and user experience. Blockchain and decentralized finance (DeFi) continue to evolve, with platforms enabling digital bond issuance and improving transparency. AI-powered due diligence tools are streamlining processes for lenders, with significant reductions in review times already observed. These financial technologies are largely in early to mid-stage implementation, with full integration expected within 2-5 years.
# TechResearcher > **AI/ML Trends Shaping Industries**
#
# **1. Generative AI Expansion:** This trend sees AI models like Google's Gemini generating diverse content beyond text, including images, video, and audio. The impact is a revolution in content creation for marketing, design, and artistic expression, with companies like Google actively developing these multimodal capabilities.
#
# **2. Agentic AI and Multi-Agent Systems:** AI agents are increasingly capable of autonomous action and decision-making. This is poised to transform fields like logistics and autonomous driving, enabling more efficient workflows and task automation.
#
# **3. Explainable AI (XAI):** Transparency in AI decision-making is crucial, especially in sensitive sectors. XAI fosters trust and helps meet regulatory requirements in healthcare and finance, ensuring AI systems are understandable and accountable.
#
# **Key Companies Involved:** Major players like Google (Gemini, Vertex AI, Imagen) are at the forefront of generative and multimodal AI. Other tech giants are also investing heavily in AI infrastructure and development.
#
# **Potential Impact:** These AI/ML advancements promise significant productivity gains, enhanced customer experiences, and the ability to solve complex problems across various industries. However, ethical considerations and regulatory frameworks are becoming increasingly important to manage their development and deployment.
# FinanceResearcher > ## Daily Executive Briefing: November 15, 2025
#
# **Key Trends:**
#
# 1.  **AI Continues its Dominant Trajectory:** Artificial intelligence remains the paramount trend across all sectors. In technology, advancements in agentic AI and context engineering are revolutionizing workflows and infrastructure demands, with a significant focus on optimizing GPU utilization. In finance, AI integration is becoming crucial for data-backed decision-making, risk assessment, and fraud detection. The healthcare sector is leveraging AI for personalized medicine, diagnostics, and drug discovery, while also exploring AI-powered mental wellness solutions.
# 2.  **Resilient Tech Sector Fueled by AI and Cloud:** The technology sector, particularly driven by AI and cloud computing, is demonstrating strong momentum. Despite market volatility, significant investments in AI infrastructure are ongoing, with companies like NVIDIA and Microsoft leading the charge. Semiconductor manufacturing, exemplified by TSMC, is critical to this AI boom. Cloud infrastructure remains foundational for digital transformation, underscoring the importance of reliable and scalable computing resources.
# 3.  **Healthcare Innovation Driven by Technology and Wellness Focus:** The healthcare industry is experiencing a wave of transformation fueled by technological advancements and a growing consumer focus on wellness. Trends include the development of advanced wearables and implantable devices (like BCIs), personalized healthcare approaches, and a significant push in mental wellness solutions leveraging VR/AR and AI chatbots. The rise of functional foods and a focus on preventative health and healthy aging are also key drivers.
#
# **Market Implications:**
#
# The strong performance of the technology sector, especially AI-related stocks, is a significant driver of market gains, with historical data indicating strong November trends for tech and consumer discretionary sectors. This optimism is further supported by cooling inflation and a favorable interest rate environment, though potential risks like rising credit risks and job market weakening persist.
#
# In finance, the market is navigating unconventional monetary policies and the rise of digital currencies, creating both opportunities and risks of market speculation. The banking sector, particularly in India, is undergoing consolidation through mega-mergers.
#
# The healthcare market is seeing innovation translate into investment, with a focus on companies developing AI-driven solutions, biotechnology, and personalized health technologies.
#
# **Top Trending Stocks (Past Week):**
#
# Based on the provided data, the following stocks show high momentum and positive sentiment, aligning with the dominant trends:
#
# 1.  **NVIDIA Corporation (NVDA):** Continues to be a leader in AI and GPU markets, with robust demand for its hardware driving exceptional momentum.
# 2.  **Microsoft Corporation (MSFT):** Benefits from its diversified business model, including cloud (Azure) and AI integration across its product suite, demonstrating steady momentum.
# 3.  **Taiwan Semiconductor Manufacturing Company (TSMC) (TSM):** As the world's largest chip foundry, TSMC is essential for AI chip production, with significant growth driven by demand for advanced nodes.
# 4.  **Robinhood Markets Inc (HOOD):** Shows exceptional one-year performance, indicating strong current market interest and growth.
#
# **Verdict and Future Outlook:**
#
# The identified stocks are poised for continued **rise** in the near to medium term, driven by the overarching trends in AI, technology, and the broader market's seasonal optimism for November.
#
# *   **NVDA and MSFT:** Their strong positions in AI and cloud infrastructure, coupled with ongoing innovation, suggest sustained growth. The increasing demand for AI workloads will continue to benefit these companies.
# *   **TSMC:** Its critical role in the AI supply chain and global expansion efforts, including new fabs and government subsidies, position it for long-term success. The recent US-China deal also helps derisk geopolitical concerns.
# *   **HOOD:** While its past performance is strong, its future trajectory will depend on its ability to maintain user growth and navigate the evolving fintech landscape, which is increasingly influenced by AI and digital assets.
#
# **Future Outlook:** The strong Q3 earnings and resilient consumer spending point towards a positive market sentiment heading into the year-end. However, investors should remain mindful of potential risks such as rising credit risks, geopolitical uncertainties, and the possibility of market corrections, especially concerning AI valuations. The trend towards AI integration, cloud computing, and advancements in healthcare technology will likely continue to shape market performance in the coming months.
# AggregatorAgent > ## Executive Summary: AI-Driven Transformation Across Tech, Health, and Finance
#
# Artificial intelligence is the unifying force propelling innovation across technology, healthcare, and finance. The rapid expansion of **generative AI** and the rise of **agentic AI** are revolutionizing content creation, automating complex decisions, and reshaping industries with unprecedented efficiency gains.
#
# In **technology**, advancements in AI infrastructure, particularly GPUs and cloud computing, are fueling a resilient sector. This progress is critical for the development of new AI models, including multimodal capabilities and explainable AI (XAI), which are essential for building trust and accountability.
#
# The **healthcare** sector is witnessing transformative breakthroughs, from gene therapies restoring sight and hearing to AI-driven diagnostics and personalized medicine. These innovations, powered by AI and advanced biotechnologies, promise to significantly improve patient outcomes and wellness.
#
# Similarly, **finance** is leveraging AI for enhanced risk assessment, fraud detection, and streamlining due diligence processes. Emerging technologies like blockchain and DeFi are also maturing, offering greater transparency and novel financial instruments.
#
# **Key Takeaways:**
#
# *   **AI as the Core Driver:** AI, in its various forms (generative, agentic, explainable), is the central technological trend impacting all three sectors.
# *   **Interconnected Advancements:** Progress in AI infrastructure (GPUs, cloud) directly supports breakthroughs in both healthcare and finance.
# *   **Efficiency and Personalization:** The overarching impact is increased operational efficiency, improved decision-making, and a shift towards highly personalized solutions in all domains.
# *   **Ethical and Regulatory Focus:** As AI integration deepens, ethical considerations and the need for transparent, accountable systems (XAI) become paramount, especially in sensitive sectors like healthcare and finance.

# %% [markdown]
# So far, all our workflows run from start to finish and then stop. But what if you need to review and improve an output multiple times? Next, we'll build a workflow that can loop and refine its own work.

# %% [markdown]
# # Section 5: Loop workflows - The Refinement Cycle

# %% [markdown]
# # The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# # The Solution: Iterative Refinement
#
# When a task needs to be improved through cycles of feedback and revision, you can use a LoopAgent. A LoopAgent runs a set of sub-agents repeatedly until a specific condition is met or a maximum number of iterations is reached. This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# # Use Loop when: Iterative improvement is needed, quality refinement matters, or you need repeated cycles.
#
#
# Architecture: Story Writing & Critique Loop
#
# <img src="/Users/mario/Desktop/kaggle/Day-1-B/5.png"/>

# %%
# Iterative Story Refinement
# we will build a system - a system with two agent
# 1) Writer Agent - Writes a draft of a short story
# 2) Critic Agent - Reviews and Critiques the story to suggest improvements

# %%
initial_writer = Agent(
    name="InitialWriter",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options = retry_config,
    ),
    instruction = """Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story"
)
print("INitial draft agent created")
# Out:
# INitial draft agent created

# %%
# this agent only critiques the work of the previous agent, gives feedback or the approval signal. it has no tools
critique_agent = Agent(
    name="CritiqueAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options = retry_config
    ),
    instruction = """You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique"
)
print("Critique agent done")
# Out:
# Critique agent done

# %% [markdown]
# Now, we need a way for the loop to actually stop based on the critic's feedback. The LoopAgent itself doesn't automatically know that "APPROVED" means "stop."
#
# We need an agent to give it an explicit signal to terminate the loop.
#
# We do this in two parts:
#
# A simple Python function that the LoopAgent understands as an "exit" signal.
# An agent that can call that function when the right condition is met.
# First, you'll define the exit_loop function:

# %%
def exit_loop():
    """ Call this function only when the critique is 'APPROVED', indicating the story is finished and no more changes
    are needed."""
    return {"status":"approved", "message":"Story approved. Exiting refinement loop."}
print("exit loop function created.")
# Out:
# exit loop function created.

# %% [markdown]
# To let an agent call this Python function, we wrap it in a FunctionTool. Then, we create a RefinerAgent that has this tool.
#
# 👉 Notice its instructions: this agent is the "brain" of the loop. It reads the {critique} from the CriticAgent and decides whether to (1) call the exit_loop tool or (2) rewrite the story.

# %%
# this agent is responsible for the refinement of the story based on critique or calls the exit loop function
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options = retry_config
    ),
    instruction = """You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key = "current_story",
    tools = [FunctionTool(exit_loop)], # we have initialized our tool with correct function reference
)
print("refiner_agent created")
# Out:
# refiner_agent created

# %% [markdown]
# Then we bring the agents together under a loop agent, which is itself nested inside of a sequential agent.
#
# This design ensures that the system first produces an initial story draft, then the refinement loop runs up to the specified number of max_iterations:

# %%
# the loop agent contains the agent that will run repeatedly: critic -> refiner
story_refinement_loop = LoopAgent(
    name="StoryRefinementAgent",
    sub_agents = [critique_agent, refiner_agent],
    max_iterations = 3 # prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents = [initial_writer, story_refinement_loop],

)
print("loop and sequential agents created")
# Out:
# loop and sequential agents created

# %%
runner = InMemoryRunner(agent = root_agent)
response = await runner.run_debug("IN a galaxy far far away where anakin was a farmer")
# Out:
#  ### Created new session: debug_session_id
#
# User > IN a galaxy far far away where anakin was a farmer
# InitialWriter > Anakin Skywalker, not a Jedi Knight, but a moisture farmer on Tatooine, squinted against the twin suns. The dry wind whipped sand against his goggles. His hands, usually steady on a lightsaber, were calloused from wrestling with stubborn vaporators. Today, a familiar, gnawing unease settled in his gut. He’d had dreams again, strange flashes of power and darkness, a voice whispering of destiny. He dismissed them as the heat playing tricks. He had crops to tend, not galactic empires to conquer. Still, as he trudged back to his small homestead, a flicker of something – impatience, perhaps, or a nascent rage – sparked within him, a seed waiting for the right kind of soil to bloom.
# CritiqueAgent > The story presents an intriguing premise, but needs some development. Here are a few suggestions:
#
# 1.  **Elaborate on the "dreams":** The "strange flashes of power and darkness" and the "voice whispering of destiny" are currently vague. Providing a more concrete, albeit brief, glimpse into these dreams would enhance their impact and Anakin's internal conflict. What does he see? What does the voice say specifically? Even a single, evocative image or phrase would make this more compelling.
#
# 2.  **Show, don't just tell, his "nascent rage":** While the story mentions "a flicker of something – impatience, perhaps, or a nascent rage," it would be more effective to demonstrate this through his actions or internal monologue in a specific moment. Perhaps he kicks a stubborn piece of equipment, has a harsh thought about his situation, or reacts poorly to a minor inconvenience. This would make the internal spark feel more tangible.
#
# 3.  **Hint at external influences or future events:** The story sets up Anakin's potential, but a slight nudge towards *why* this "seed" might find fertile soil would strengthen the narrative hook. This could be as subtle as a brief mention of the Empire's presence on Tatooine (even if he doesn't fully grasp it), or a passing thought about the injustice he perceives in his life, hinting at the kind of environment that could cultivate his darker impulses.
# RefinerAgent > Anakin Skywalker, not a Jedi Knight, but a moisture farmer on Tatooine, squinted against the twin suns. The dry wind whipped sand against his goggles. His hands, usually steady on a lightsaber, were calloused from wrestling with stubborn vaporators. Today, a familiar, gnawing unease settled in his gut. He’d had dreams again – flashes of choking sand, a vision of a golden hand reaching for him, and a sibilant voice whispering, "You can save her… you must embrace the power." He shook his head, dismissing them as the heat playing tricks. He had crops to tend, not galactic empires to conquer. Still, as he trudged back to his small homestead, a vaporator sputtered and died with a defiant hiss. Anakin kicked its metal casing, a surge of frustration boiling within him. "Stupid piece of junk!" he spat, the words raw with an impatience that bordered on rage. He knew his life was destined for more than this endless toil under a merciless sun. He’d seen the Imperial patrols, symbols of a power that cared nothing for the lives of moisture farmers. It fueled a resentment that simmered beneath the surface, a seed waiting for the right kind of soil to bloom.
# CritiqueAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# CritiqueAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %% [markdown]
# # Section 6 - Choosing the RIGHT pattern
#
# Decision tree: which workflow pattern?
#
# <img src="/Users/mario/Desktop/kaggle/Day-1-B/6.png"/>

# %% [markdown]
# # quick reference table
# <img src="/Users/mario/Desktop/kaggle/Day-1-B/7.png"/>
