# %%
import os
from dotenv import load_dotenv
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

# %%
# For local development, you don't need url_prefix
# url_prefix = get_adk_proxy_url()  # This only works on Kaggle
print("Running locally - skipping Kaggle-specific setup")
# Out:
# Running locally - skipping Kaggle-specific setup

# %%
# !adk web --url_prefix {url_prefix}
# Out:
# /Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [49028]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started server process [49028]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:50753 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50753 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50753 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50753 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50764 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50764 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50784 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50784 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50784 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50784 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50789 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50789 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50799 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50799 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:50799 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:50799 - "GET /proxy/8000/dev-ui/ HTTP/1.1" 404 Not Found
# ^C
# INFO:     Finished server process [49028]
# ERROR:    Traceback (most recent call last):
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 712, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 683, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 2042, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!
# ^C
# INFO:     Finished server process [49028]
# ERROR:    Traceback (most recent call last):
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 712, in run_until_complete
#     self.run_forever()
#     ~~~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 683, in run_forever
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/base_events.py", line 2042, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/Users/mario/Desktop/kaggle/kaggle/lib/python3.13/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mario/.pyenv/versions/3.13.5/lib/python3.13/asyncio/queues.py", line 186, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!

# %%
url_prefix = get_adk_proxy_url()
